# %%
import pandas as pd
import matplotlib.pyplot as plt  
import numpy as np 
import seaborn as sns

# %%
dataset = pd.read_csv('sale.csv', encoding ='ISO-8859-1')

# %%
dataset.head(2)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30      95.70                2  2871.0
# 1        10121               34      81.35                5  2765.9
#
#         ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0  2/24/2003 0:00  Shipped       1         2     2003  ...
# 1   5/7/2003 0:00  Shipped       2         5     2003  ...
#
#               ADDRESSLINE1  ADDRESSLINE2   CITY STATE POSTALCODE COUNTRY  \
# 0  897 Long Airport Avenue           NaN    NYC    NY      10022     USA
# 1       59 rue de l'Abbaye           NaN  Reims   NaN      51100  France
#
#   TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0       NaN              Yu             Kwai    Small
# 1      EMEA         Henriot             Paul    Small
#
# [2 rows x 25 columns]

# %%
dataset.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

impute=SimpleImputer(strategy='most_frequent')

obj_columns=dataset.select_dtypes(include='object').columns

for column in obj_columns:
  dataset[[column]]=impute.fit_transform(dataset[[column]])

dataset
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
dataset.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# ADDRESSLINE2        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
dataset['ORDERDATE']=pd.to_datetime(dataset['ORDERDATE'])
dataset
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
#Sales over time monthly

monthly_sales=dataset.resample('M',on='ORDERDATE')[['SALES']].sum()
monthly_sales.plot(title='Sales Over time monthly', color = 'purple')
# Out:
# <Axes: title={'center': 'Sales Over time monthly'}, xlabel='ORDERDATE'>

# %%
#PRODUCT BASED CATEGORY SALES PERFORMANCE

product=dataset.groupby('PRODUCTLINE')[['SALES']].sum()
product.sort_values(by='SALES',ascending=False).plot(kind='bar', color ='pink')
# Out:
# <Axes: xlabel='PRODUCTLINE'>

# %%
#PRODUCT BASED CATEGORY QUANTITY BASED PERFORMANCE

quantity=dataset.groupby('PRODUCTLINE')[['QUANTITYORDERED']].sum()
quantity.sort_values(by='QUANTITYORDERED',ascending=False).plot(kind='bar', color= 'gray')
# Out:
# <Axes: xlabel='PRODUCTLINE'>

# %%
#Sales By country
import matplotlib.pyplot as plt
country=dataset.groupby('COUNTRY')[['SALES']].sum()
country.sort_values(by='SALES',ascending=False).plot(kind='bar',color='blue')
plt.title('SALES BY COUNTRY')
plt.xlabel('Country')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
s=dataset.groupby('STATE')[['MSRP']].sum()
s
# Out:
#                  MSRP
# STATE
# BC               4583
# CA             191269
# CT               6516
# Isle of Wight    2327
# MA              18946
# NH               3570
# NJ               1959
# NSW              9099
# NV               2805
# NY              18252
# Osaka            2033
# PA               8032
# Quebec           2358
# Queensland       1673
# Tokyo            3177
# Victoria         7721

# %% [markdown]
# Customer Segmentation

# %%
from datetime import datetime


# Calculating Recency - days since last order
current_date = dataset['ORDERDATE'].max() + pd.Timedelta(days=1)
dataset['Recency'] = (current_date - dataset.groupby('CUSTOMERNAME')['ORDERDATE'].transform('max')).dt.days

# Calculating Frequency - number of orders per customer
dataset['Frequency'] = dataset.groupby('CUSTOMERNAME')['ORDERNUMBER'].transform('nunique')

# Calculating Monetary - total sales per customer
dataset['Monetary'] = dataset.groupby('CUSTOMERNAME')['SALES'].transform('sum')

# Creating a new dataframe for RFM analysis
rfm_dataset = dataset[['CUSTOMERNAME', 'Recency', 'Frequency', 'Monetary']].drop_duplicates()

rfm_dataset
# Out:
#                            CUSTOMERNAME  Recency  Frequency   Monetary
# 0                     Land of Toys Inc.      198          4  164069.44
# 1                    Reims Collectables       63          5  135042.94
# 2                       Lyon Souveniers       76          3   78570.34
# 3                     Toys4GrownUps.com      140          3  104561.96
# 4              Corporate Gift Ideas Co.       98          4  149882.50
# ..                                  ...      ...        ...        ...
# 483        Australian Collectables, Ltd       23          3   64591.46
# 554                    Gift Ideas Corp.      179          3   57294.42
# 567  Bavarian Collectables Imports, Co.      259          1   34993.92
# 571                        Royale Belge      142          4   33440.10
# 937             Auto-Moto Classics Inc.      180          3   26479.26
#
# [92 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Scaling the RFM data
scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm_dataset[['Recency', 'Frequency', 'Monetary']])

# Determining the optimal number of clusters using the elbow method
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(rfm_scaled)
    inertia.append(kmeans.inertia_)

# Plotting the elbow plot
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), inertia, marker='o', linestyle='--')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.xticks(np.arange(1, 11, 1))
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(rfm_scaled)


rfm_dataset['Clusters']=(kmeans.labels_)
rfm_dataset
# Out:
#                            CUSTOMERNAME  Recency  Frequency   Monetary  \
# 0                     Land of Toys Inc.      198          4  164069.44
# 1                    Reims Collectables       63          5  135042.94
# 2                       Lyon Souveniers       76          3   78570.34
# 3                     Toys4GrownUps.com      140          3  104561.96
# 4              Corporate Gift Ideas Co.       98          4  149882.50
# ..                                  ...      ...        ...        ...
# 483        Australian Collectables, Ltd       23          3   64591.46
# 554                    Gift Ideas Corp.      179          3   57294.42
# 567  Bavarian Collectables Imports, Co.      259          1   34993.92
# 571                        Royale Belge      142          4   33440.10
# 937             Auto-Moto Classics Inc.      180          3   26479.26
#
#      Clusters
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# ...

# %%
r=rfm_dataset.groupby('Clusters')[['Recency','Frequency','Monetary']].mean()
r
# Out:
#              Recency  Frequency       Monetary
# Clusters
# 0         326.866667   2.033333   72467.857333
# 1         116.833333   3.383333  104857.349333
# 2           2.000000  21.500000  783576.085000

# %%
def func(row):
  if row['Clusters']==1:
    return 'Best Customer'

  elif row['Clusters']==0:
    return ' Average Customer'

  else:
    return 'Bad Customer'

# %%
rfm_dataset['Clusters']=rfm_dataset.apply(func,axis=1)
rfm_dataset
# Out:
#                            CUSTOMERNAME  Recency  Frequency   Monetary  \
# 0                     Land of Toys Inc.      198          4  164069.44
# 1                    Reims Collectables       63          5  135042.94
# 2                       Lyon Souveniers       76          3   78570.34
# 3                     Toys4GrownUps.com      140          3  104561.96
# 4              Corporate Gift Ideas Co.       98          4  149882.50
# ..                                  ...      ...        ...        ...
# 483        Australian Collectables, Ltd       23          3   64591.46
# 554                    Gift Ideas Corp.      179          3   57294.42
# 567  Bavarian Collectables Imports, Co.      259          1   34993.92
# 571                        Royale Belge      142          4   33440.10
# 937             Auto-Moto Classics Inc.      180          3   26479.26
#
#               Clusters
# 0        Best Customer
# 1        Best Customer
# 2        Best Customer
# ...

# %%
rfm_dataset['Clusters'].value_counts().sort_values(ascending=False).plot(kind='barh',color=['blue','purple','gray'])
# Out:
# <Axes: ylabel='Clusters'>
